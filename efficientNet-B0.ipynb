# %% [markdown]
# # 라이브러리 로드 및 필요 함수 정의

# %%
import warnings
warnings.filterwarnings('ignore')

from glob import glob
import pandas as pd
import numpy as np 
from tqdm import tqdm
import json
import cv2
import matplotlib.pyplot as plt

import os
import timm
import random

import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torchvision.transforms as transforms
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score 
import time

# %%
# score 계산
def accuracy_function(real, pred):                   # https://dacon.io/competitions/official/235870/codeshare/4146
    score = f1_score(real, pred, average='macro')
    return score

# torch model 저장
def model_save(model, score,  path):
    os.makedirs('model', exist_ok=True) # if no path , will make new path and save there
    torch.save({
        'model': model.state_dict(),
        'score': score
    }, path)

# %% [markdown]
# # 데이터 로드

# %%
sorted(glob('dataset/train/train/*/*.json'))
# Out:
# ['dataset/train/train\\10027\\10027.json',
#  'dataset/train/train\\10037\\10037.json',
#  'dataset/train/train\\10043\\10043.json',
#  'dataset/train/train\\10045\\10045.json',
#  'dataset/train/train\\10063\\10063.json',
#  'dataset/train/train\\10090\\10090.json',
#  'dataset/train/train\\10109\\10109.json',
#  'dataset/train/train\\10115\\10115.json',
#  'dataset/train/train\\10117\\10117.json',
#  'dataset/train/train\\10118\\10118.json',
#  'dataset/train/train\\10124\\10124.json',
#  'dataset/train/train\\10169\\10169.json',
#  'dataset/train/train\\10173\\10173.json',
#  'dataset/train/train\\10192\\10192.json',
#  'dataset/train/train\\10199\\10199.json',
#  'dataset/train/train\\10201\\10201.json',
#  'dataset/train/train\\10224\\10224.json',
#  'dataset/train/train\\10226\\10226.json',
#  'dataset/train/train\\10238\\10238.json',
#  'dataset/train/train\\10251\\10251.json',
#  'dataset/train/train\\10252\\10252.json',
#  'dataset/train/train\\10263\\10263.json',
#  'dataset/train/train\\10274\\10274.json',
#  'dataset/train/train\\10299\\10299.json',
#  'dataset/train/train\\10300\\10300.json',
#  'dataset/train/train\\10304\\10304.json',
#  'dataset/train/train\\10323\\10323.json',
#  'dataset/train/train\\10328\\10328.json',
#  'dataset/train/train\\10345\\10345.json',
#  'dataset/train/train\\10348\\10348.json',
#  'dataset/train/train\\10365\\10365.json',
#  'dataset/train/train\\10369\\10369.json',
#  'dataset/train/train\\10418\\10418.json',
#  'dataset/train/train\\10419\\10419.json',
#  'dataset/train/train\\10421\\10421.json',
#  'dataset/train/train\\10442\\10442.json',
#  'dataset/train/train\\10462\\10462.json',
#  'dataset/train/train\\10478\\10478.json',
#  'dataset/train/train\\10480\\10480.json',
#  'dataset/train/train\\10496\\10496.json',
#  'dataset/train/train\\10505\\10505.json',
#  'dataset/train/train\\10513\\10513.json',
#  'dataset/train/train\\10519\\10519.json',
#  'dataset/train/train\\10523\\10523.json',
#  'dataset/train/train\\10525\\10525.json',
#  'dataset/train/train\\10540\\10540.json',
#  'dataset/train/train\\10546\\10546.json',
#  'dataset/train/train\\10549\\10549.json',
#  'dataset/train/train\\10601\\10601.json',
#  'dataset/train/train\\10612\\10612.json',
#  'dataset/train/train\\10635\\10635.json',
#  'dataset/train/train\\10649\\10649.json',
#  'dataset/train/train\\10652\\10652.json',
#  'dataset/train/train\\10653\\10653.json',
#  'dataset/train/train\\10677\\10677.json',
#  'dataset/train/train\\10682\\10682.json',
#  'dataset/train/train\\10693\\10693.json',
#  'dataset/train/train\\10706\\10706.json',
#  'dataset/train/train\\10721\\10721.json',
#  'dataset/train/train\\10733\\10733.json',
#  'dataset/train/train\\10738\\10738.json',
#  'dataset/train/train\\10764\\10764.json',
#  'dataset/train/train\\10813\\10813.json',
#  'dataset/train/train\\10817\\10817.json',
#  'dataset/train/train\\10826\\10826.json',
#  'dataset/train/train\\10828\\10828.json',
#  'dataset/train/train\\10834\\10834.json',
#  'dataset/train/train\\10847\\10847.json',
#  'dataset/train/train\\10850\\10850.json',
#  'dataset/train/train\\10851\\10851.json',
#  'dataset/train/train\\10858\\10858.json',
#  'dataset/train/train\\10862\\10862.json',
#  'dataset/train/train\\10864\\10864.json',
#  'dataset/train/train\\10879\\10879.json',
#  'dataset/train/train\\10880\\10880.json',
#  'dataset/train/train\\10882\\10882.json',
#  'dataset/train/train\\10908\\10908.json',
#  'dataset/train/train\\10922\\10922.json',
#  'dataset/train/train\\10925\\10925.json',
#  'dataset/train/train\\10927\\10927.json',
#  'dataset/train/train\\10945\\10945.json',
#  'dataset/train/train\\10950\\10950.json',
#  'dataset/train/train\\10970\\10970.json',
#  'dataset/train/train\\10983\\10983.json',
#  'dataset/train/train\\10991\\10991.json',
#  'dataset/train/train\\10997\\10997.json',
#  'dataset/train/train\\11003\\11003.json',
#  'dataset/train/train\\11040\\11040.json',
#  'dataset/train/train\\11045\\11045.json',
#  'dataset/train/train\\11050\\11050.json',
#  'dataset/train/train\\11058\\11058.json',
#  'dataset/train/train\\11087\\11087.json',
#  'dataset/train/train\\11107\\11107.json',
#  'dataset/train/train\\11119\\11119.json',
#  'dataset/train/train\\11122\\11122.json',
#  'dataset/train/train\\11134\\11134.json',
#  'dataset/train/train\\11138\\11138.json',
#  'dataset/train/train\\11148\\11148.json',
#  'dataset/train/train\\11149\\11149.json',
#  'dataset/train/train\\11150\\11150.json',
#  'dataset/train/train\\11159\\11159.json',
#  'dataset/train/train\\11165\\11165.json',
#  'dataset/train/train\\11179\\11179.json',
#  'dataset/train/train\\11193\\11193.json',
#  'dataset/train/train\\11198\\11198.json',
#  'dataset/train/train\\11221\\11221.json',
#  'dataset/train/train\\11225\\11225.json',
#  'dataset/train/train\\11231\\11231.json',
#  'dataset/train/train\\11233\\11233.json',
#  'dataset/train/train\\11242\\11242.json',
#  'dataset/train/train\\11261\\11261.json',
#  'dataset/train/train\\11292\\11292.json',
#  'dataset/train/train\\11295\\11295.json',
#  'dataset/train/train\\11314\\11314.json',
#  'dataset/train/train\\11321\\11321.json',
#  'dataset/train/train\\11333\\11333.json',
#  'dataset/train/train\\11335\\11335.json',
#  'dataset/train/train\\11346\\11346.json',
#  'dataset/train/train\\11350\\11350.json',
#  'dataset/train/train\\11358\\11358.json',
#  'dataset/train/train\\11364\\11364.json',
#  'dataset/train/train\\11400\\11400.json',
#  'dataset/train/train\\11402\\11402.json',
#  'dataset/train/train\\11403\\11403.json',
#  'dataset/train/train\\12152\\12152.json',
#  'dataset/train/train\\12158\\12158.json',
#  'dataset/train/train\\12164\\12164.json',
#  'dataset/train/train\\12173\\12173.json',
#  'dataset/train/train\\12179\\12179.json',
#  'dataset/train/train\\12185\\12185.json',
#  'dataset/train/train\\12190\\12190.json',
#  'dataset/train/train\\12197\\12197.json',
#  'dataset/train/train\\12203\\12203.json',
#  'dataset/train/train\\12205\\12205.json',
#  'dataset/train/train\\12214\\12214.json',
#  'dataset/train/train\\12217\\12217.json',
#  'dataset/train/train\\12225\\12225.json',
#  'dataset/train/train\\12231\\12231.json',
#  'dataset/train/train\\12232\\12232.json',
#  'dataset/train/train\\12239\\12239.json',
#  'dataset/train/train\\12240\\12240.json',
#  'dataset/train/train\\12253\\12253.json',
#  'dataset/train/train\\12256\\12256.json',
#  'dataset/train/train\\12258\\12258.json',
#  'dataset/train/train\\12276\\12276.json',
#  'dataset/train/train\\12283\\12283.json',
#  'dataset/train/train\\12285\\12285.json',
#  'dataset/train/train\\12290\\12290.json',
#  'dataset/train/train\\12294\\12294.json',
#  'dataset/train/train\\12299\\12299.json',
#  'dataset/train/train\\12310\\12310.json',
#  'dataset/train/train\\12344\\12344.json',
#  'dataset/train/train\\12348\\12348.json',
#  'dataset/train/train\\12356\\12356.json',
#  'dataset/train/train\\12357\\12357.json',
#  'dataset/train/train\\12361\\12361.json',
#  'dataset/train/train\\12389\\12389.json',
#  'dataset/train/train\\12422\\12422.json',
#  'dataset/train/train\\12446\\12446.json',
#  'dataset/train/train\\12448\\12448.json',
#  'dataset/train/train\\12452\\12452.json',
#  'dataset/train/train\\12455\\12455.json',
#  'dataset/train/train\\12470\\12470.json',
#  'dataset/train/train\\12476\\12476.json',
#  'dataset/train/train\\12483\\12483.json',
#  'dataset/train/train\\12485\\12485.json',
#  'dataset/train/train\\12504\\12504.json',
#  'dataset/train/train\\12515\\12515.json',
#  'dataset/train/train\\12519\\12519.json',
#  'dataset/train/train\\12522\\12522.json',
#  'dataset/train/train\\12536\\12536.json',
#  'dataset/train/train\\12543\\12543.json',
#  'dataset/train/train\\12550\\12550.json',
#  'dataset/train/train\\12576\\12576.json',
#  'dataset/train/train\\12589\\12589.json',
#  'dataset/train/train\\12591\\12591.json',
#  'dataset/train/train\\12598\\12598.json',
#  'dataset/train/train\\12604\\12604.json',
#  'dataset/train/train\\12652\\12652.json',
#  'dataset/train/train\\12655\\12655.json',
#  'dataset/train/train\\12679\\12679.json',
#  'dataset/train/train\\12683\\12683.json',
#  'dataset/train/train\\12692\\12692.json',
#  'dataset/train/train\\12696\\12696.json',
#  'dataset/train/train\\12698\\12698.json',
#  'dataset/train/train\\12712\\12712.json',
#  'dataset/train/train\\12716\\12716.json',
#  'dataset/train/train\\12721\\12721.json',
#  'dataset/train/train\\12723\\12723.json',
#  'dataset/train/train\\12727\\12727.json',
#  'dataset/train/train\\12734\\12734.json',
#  'dataset/train/train\\12738\\12738.json',
#  'dataset/train/train\\12748\\12748.json',
#  'dataset/train/train\\12770\\12770.json',
#  'dataset/train/train\\14212\\14212.json',
#  'dataset/train/train\\14223\\14223.json',
#  'dataset/train/train\\14236\\14236.json',
#  'dataset/train/train\\14239\\14239.json',
#  'dataset/train/train\\14247\\14247.json',
#  'dataset/train/train\\14248\\14248.json',
#  'dataset/train/train\\14268\\14268.json',
#  'dataset/train/train\\14273\\14273.json',
#  'dataset/train/train\\14275\\14275.json',
#  'dataset/train/train\\14291\\14291.json',
#  'dataset/train/train\\14314\\14314.json',
#  'dataset/train/train\\14317\\14317.json',
#  'dataset/train/train\\14322\\14322.json',
#  'dataset/train/train\\14324\\14324.json',
#  'dataset/train/train\\14353\\14353.json',
#  'dataset/train/train\\14358\\14358.json',
#  'dataset/train/train\\14363\\14363.json',
#  'dataset/train/train\\14369\\14369.json',
#  'dataset/train/train\\14404\\14404.json',
#  'dataset/train/train\\14405\\14405.json',
#  'dataset/train/train\\14411\\14411.json',
#  'dataset/train/train\\14412\\14412.json',
#  'dataset/train/train\\14417\\14417.json',
#  'dataset/train/train\\14419\\14419.json',
#  'dataset/train/train\\14423\\14423.json',
#  'dataset/train/train\\14438\\14438.json',
#  'dataset/train/train\\14445\\14445.json',
#  'dataset/train/train\\14468\\14468.json',
#  'dataset/train/train\\14471\\14471.json',
#  'dataset/train/train\\14481\\14481.json',
#  'dataset/train/train\\14490\\14490.json',
#  'dataset/train/train\\14495\\14495.json',
#  'dataset/train/train\\14498\\14498.json',
#  'dataset/train/train\\14507\\14507.json',
#  'dataset/train/train\\14518\\14518.json',
#  'dataset/train/train\\14529\\14529.json',
#  'dataset/train/train\\14545\\14545.json',
#  'dataset/train/train\\14568\\14568.json',
#  'dataset/train/train\\14577\\14577.json',
#  'dataset/train/train\\14585\\14585.json',
#  'dataset/train/train\\14601\\14601.json',
#  'dataset/train/train\\14623\\14623.json',
#  'dataset/train/train\\14646\\14646.json',
#  'dataset/train/train\\14649\\14649.json',
#  'dataset/train/train\\14659\\14659.json',
#  'dataset/train/train\\14669\\14669.json',
#  'dataset/train/train\\14694\\14694.json',
#  'dataset/train/train\\14702\\14702.json',
#  'dataset/train/train\\14722\\14722.json',
#  'dataset/train/train\\14723\\14723.json',
#  'dataset/train/train\\14756\\14756.json',
#  'dataset/train/train\\14772\\14772.json',
#  'dataset/train/train\\14780\\14780.json',
#  'dataset/train/train\\14796\\14796.json',
#  'dataset/train/train\\14802\\14802.json',
#  'dataset/train/train\\14812\\14812.json',
#  'dataset/train/train\\14814\\14814.json',
#  'dataset/train/train\\14824\\14824.json',
#  'dataset/train/train\\14835\\14835.json',
#  'dataset/train/train\\14841\\14841.json',
#  'dataset/train/train\\14873\\14873.json',
#  'dataset/train/train\\14876\\14876.json',
#  'dataset/train/train\\14879\\14879.json',
#  'dataset/train/train\\14895\\14895.json',
#  'dataset/train/train\\14926\\14926.json',
#  'dataset/train/train\\14943\\14943.json',
#  'dataset/train/train\\14949\\14949.json',
#  'dataset/train/train\\14955\\14955.json',
#  'dataset/train/train\\14957\\14957.json',
#  'dataset/train/train\\14963\\14963.json',
#  'dataset/train/train\\18204\\18204.json',
#  'dataset/train/train\\18212\\18212.json',
#  'dataset/train/train\\18248\\18248.json',
#  'dataset/train/train\\18257\\18257.json',
#  'dataset/train/train\\18267\\18267.json',
#  'dataset/train/train\\18273\\18273.json',
#  'dataset/train/train\\18274\\18274.json',
#  'dataset/train/train\\18302\\18302.json',
#  'dataset/train/train\\18321\\18321.json',
#  'dataset/train/train\\18329\\18329.json',
#  'dataset/train/train\\18333\\18333.json',
#  'dataset/train/train\\18343\\18343.json',
#  'dataset/train/train\\18352\\18352.json',
#  'dataset/train/train\\18391\\18391.json',
#  'dataset/train/train\\18408\\18408.json',
#  'dataset/train/train\\18418\\18418.json',
#  'dataset/train/train\\18425\\18425.json',
#  'dataset/train/train\\18437\\18437.json',
#  'dataset/train/train\\18441\\18441.json',
#  'dataset/train/train\\18450\\18450.json',
#  'dataset/train/train\\18459\\18459.json',
#  'dataset/train/train\\18464\\18464.json',
#  'dataset/train/train\\18480\\18480.json',
#  'dataset/train/train\\18481\\18481.json',
#  'dataset/train/train\\18496\\18496.json',
#  'dataset/train/train\\18499\\18499.json',
#  'dataset/train/train\\18525\\18525.json',
#  'dataset/train/train\\18529\\18529.json',
#  'dataset/train/train\\18559\\18559.json',
#  'dataset/train/train\\18575\\18575.json',
#  'dataset/train/train\\18590\\18590.json',
#  'dataset/train/train\\18591\\18591.json',
#  'dataset/train/train\\18601\\18601.json',
#  'dataset/train/train\\18619\\18619.json',
#  'dataset/train/train\\18621\\18621.json',
#  'dataset/train/train\\18633\\18633.json',
#  'dataset/train/train\\18644\\18644.json',
#  'dataset/train/train\\18646\\18646.json',
#  'dataset/train/train\\18648\\18648.json',
#  'dataset/train/train\\18649\\18649.json',
#  'dataset/train/train\\18652\\18652.json',
#  'dataset/train/train\\18672\\18672.json',
#  'dataset/train/train\\18683\\18683.json',
#  'dataset/train/train\\18686\\18686.json',
#  'dataset/train/train\\18696\\18696.json',
#  'dataset/train/train\\18697\\18697.json',
#  'dataset/train/train\\18711\\18711.json',
#  'dataset/train/train\\18713\\18713.json',
#  'dataset/train/train\\18718\\18718.json',
#  'dataset/train/train\\18724\\18724.json',
#  'dataset/train/train\\18726\\18726.json',
#  'dataset/train/train\\18733\\18733.json',
#  'dataset/train/train\\18741\\18741.json',
#  'dataset/train/train\\18751\\18751.json',
#  'dataset/train/train\\18753\\18753.json',
#  'dataset/train/train\\18755\\18755.json',
#  'dataset/train/train\\18787\\18787.json',
#  'dataset/train/train\\18788\\18788.json',
#  'dataset/train/train\\18798\\18798.json',
#  'dataset/train/train\\18804\\18804.json',
#  'dataset/train/train\\18830\\18830.json',
#  'dataset/train/train\\18831\\18831.json',
#  'dataset/train/train\\18841\\18841.json',
#  'dataset/train/train\\18848\\18848.json',
#  'dataset/train/train\\18867\\18867.json',
#  'dataset/train/train\\18870\\18870.json',
#  'dataset/train/train\\18875\\18875.json',
#  'dataset/train/train\\18891\\18891.json',
#  'dataset/train/train\\18897\\18897.json',
#  'dataset/train/train\\18901\\18901.json',
#  'dataset/train/train\\18910\\18910.json',
#  'dataset/train/train\\18934\\18934.json',
#  'dataset/train/train\\18941\\18941.json',
#  'dataset/train/train\\18946\\18946.json',
#  'dataset/train/train\\18949\\18949.json',
#  'dataset/train/train\\18951\\18951.json',
#  'dataset/train/train\\18958\\18958.json',
#  'dataset/train/train\\18961\\18961.json',
#  'dataset/train/train\\18974\\18974.json',
#  'dataset/train/train\\18978\\18978.json',
#  'dataset/train/train\\18980\\18980.json',
#  'dataset/train/train\\18982\\18982.json',
#  'dataset/train/train\\18989\\18989.json',
#  'dataset/train/train\\18996\\18996.json',
#  'dataset/train/train\\19011\\19011.json',
#  'dataset/train/train\\19016\\19016.json',
#  'dataset/train/train\\19019\\19019.json',
#  'dataset/train/train\\19048\\19048.json',
#  'dataset/train/train\\19060\\19060.json',
#  'dataset/train/train\\19076\\19076.json',
#  'dataset/train/train\\19081\\19081.json',
#  'dataset/train/train\\19093\\19093.json',
#  'dataset/train/train\\19103\\19103.json',
#  'dataset/train/train\\19111\\19111.json',
#  'dataset/train/train\\19120\\19120.json',
#  'dataset/train/train\\19132\\19132.json',
#  'dataset/train/train\\19138\\19138.json',
#  'dataset/train/train\\19143\\19143.json',
#  'dataset/train/train\\19156\\19156.json',
#  'dataset/train/train\\19158\\19158.json',
#  'dataset/train/train\\19162\\19162.json',
#  'dataset/train/train\\19163\\19163.json',
#  'dataset/train/train\\19165\\19165.json',
#  'dataset/train/train\\19166\\19166.json',
#  'dataset/train/train\\19167\\19167.json',
#  'dataset/train/train\\19169\\19169.json',
#  'dataset/train/train\\19175\\19175.json',
#  'dataset/train/train\\19178\\19178.json',
#  'dataset/train/train\\19189\\19189.json',
#  'dataset/train/train\\19211\\19211.json',
#  'dataset/train/train\\19235\\19235.json',
#  'dataset/train/train\\19238\\19238.json',
#  'dataset/train/train\\19242\\19242.json',
#  'dataset/train/train\\19250\\19250.json',
#  'dataset/train/train\\19255\\19255.json',
#  'dataset/train/train\\19262\\19262.json',
#  'dataset/train/train\\19271\\19271.json',
#  'dataset/train/train\\19275\\19275.json',
#  'dataset/train/train\\19288\\19288.json',
#  'dataset/train/train\\19290\\19290.json',
#  'dataset/train/train\\19294\\19294.json',
#  'dataset/train/train\\19303\\19303.json',
#  'dataset/train/train\\19305\\19305.json',
#  'dataset/train/train\\19340\\19340.json',
#  'dataset/train/train\\19356\\19356.json',
#  'dataset/train/train\\19362\\19362.json',
#  'dataset/train/train\\19364\\19364.json',
#  'dataset/train/train\\19371\\19371.json',
#  'dataset/train/train\\19403\\19403.json',
#  'dataset/train/train\\19405\\19405.json',
#  'dataset/train/train\\19414\\19414.json',
#  'dataset/train/train\\19417\\19417.json',
#  'dataset/train/train\\19446\\19446.json',
#  'dataset/train/train\\19452\\19452.json',
#  'dataset/train/train\\19453\\19453.json',
#  'dataset/train/train\\19455\\19455.json',
#  'dataset/train/train\\19471\\19471.json',
#  'dataset/train/train\\19492\\19492.json',
#  'dataset/train/train\\19496\\19496.json',
#  'dataset/train/train\\19501\\19501.json',
#  'dataset/train/train\\19503\\19503.json',
#  'dataset/train/train\\19507\\19507.json',
#  'dataset/train/train\\19511\\19511.json',
#  'dataset/train/train\\19516\\19516.json',
#  'dataset/train/train\\19519\\19519.json',
#  'dataset/train/train\\19527\\19527.json',
#  'dataset/train/train\\19541\\19541.json',
#  'dataset/train/train\\19543\\19543.json',
#  'dataset/train/train\\19546\\19546.json',
#  'dataset/train/train\\19548\\19548.json',
#  'dataset/train/train\\19551\\19551.json',
#  'dataset/train/train\\19558\\19558.json',
#  'dataset/train/train\\19560\\19560.json',
#  'dataset/train/train\\19563\\19563.json',
#  'dataset/train/train\\19574\\19574.json',
#  'dataset/train/train\\19580\\19580.json',
#  'dataset/train/train\\19586\\19586.json',
#  'dataset/train/train\\19588\\19588.json',
#  'dataset/train/train\\19598\\19598.json',
#  'dataset/train/train\\19605\\19605.json',
#  'dataset/train/train\\19619\\19619.json',
#  'dataset/train/train\\19634\\19634.json',
#  'dataset/train/train\\19645\\19645.json',
#  'dataset/train/train\\19648\\19648.json',
#  'dataset/train/train\\19667\\19667.json',
#  'dataset/train/train\\19680\\19680.json',
#  'dataset/train/train\\19682\\19682.json',
#  'dataset/train/train\\19693\\19693.json',
#  'dataset/train/train\\19697\\19697.json',
#  'dataset/train/train\\19699\\19699.json',
#  'dataset/train/train\\19705\\19705.json',
#  'dataset/train/train\\19710\\19710.json',
#  'dataset/train/train\\19712\\19712.json',
#  'dataset/train/train\\19722\\19722.json',
#  'dataset/train/train\\19741\\19741.json',
#  'dataset/train/train\\19749\\19749.json',
#  ...]

# %%
# 주어진 훈련 데이터 경로
train_csv = sorted(glob('dataset/train/train/*/*.csv')) 
train_jpg = sorted(glob('dataset/train/train/*/*.jpg'))
train_json = sorted(glob('dataset/train/train/*/*.json'))

crops = []
diseases = []
risks = []
labels = []

# 훈련데이터 로드 (in json)
for i in range(len(train_json)):
    with open(train_json[i], 'r') as f:
        sample = json.load(f)
        crop = sample["annotations"]["crop"]
        disease = sample['annotations']['disease']
        risk = sample['annotations']['risk']
        label=f"{crop}_{disease}_{risk}"

        crops.append(crop)
        diseases.append(disease)
        risks.append(risk)
        labels.append(label)
label_unique = sorted(np.unique(labels))
label_unique
# Out:
# ['1_00_0',
#  '2_00_0',
#  '2_a5_2',
#  '3_00_0',
#  '3_a9_1',
#  '3_a9_2',
#  '3_a9_3',
#  '3_b3_1',
#  '3_b6_1',
#  '3_b7_1',
#  '3_b8_1',
#  '4_00_0',
#  '5_00_0',
#  '5_a7_2',
#  '5_b6_1',
#  '5_b7_1',
#  '5_b8_1',
#  '6_00_0',
#  '6_a11_1',
#  '6_a11_2',
#  '6_a12_1',
#  '6_a12_2',
#  '6_b4_1',
#  '6_b4_3',
#  '6_b5_1']

# %%
label_unique = {key:value for key,value in zip(label_unique, range(len(label_unique)))}
label_unique
# Out:
# {'1_00_0': 0,
#  '2_00_0': 1,
#  '2_a5_2': 2,
#  '3_00_0': 3,
#  '3_a9_1': 4,
#  '3_a9_2': 5,
#  '3_a9_3': 6,
#  '3_b3_1': 7,
#  '3_b6_1': 8,
#  '3_b7_1': 9,
#  '3_b8_1': 10,
#  '4_00_0': 11,
#  '5_00_0': 12,
#  '5_a7_2': 13,
#  '5_b6_1': 14,
#  '5_b7_1': 15,
#  '5_b8_1': 16,
#  '6_00_0': 17,
#  '6_a11_1': 18,
#  '6_a11_2': 19,
#  '6_a12_1': 20,
#  '6_a12_2': 21,
#  '6_b4_1': 22,
#  '6_b4_3': 23,
#  '6_b5_1': 24}

# %%
labels = [label_unique[k] for k in labels]
labels
# Out:
# [9,
#  3,
#  3,
#  3,
#  3,
#  9,
#  9,
#  3,
#  11,
#  4,
#  0,
#  11,
#  7,
#  16,
#  9,
#  3,
#  0,
#  3,
#  7,
#  10,
#  16,
#  14,
#  0,
#  11,
#  10,
#  3,
#  8,
#  4,
#  0,
#  3,
#  9,
#  17,
#  17,
#  3,
#  17,
#  2,
#  5,
#  17,
#  2,
#  3,
#  4,
#  0,
#  1,
#  3,
#  3,
#  3,
#  3,
#  13,
#  0,
#  17,
#  0,
#  14,
#  9,
#  0,
#  3,
#  2,
#  2,
#  4,
#  0,
#  3,
#  11,
#  8,
#  3,
#  11,
#  3,
#  11,
#  3,
#  0,
#  17,
#  1,
#  14,
#  0,
#  11,
#  3,
#  14,
#  1,
#  3,
#  11,
#  17,
#  10,
#  17,
#  0,
#  3,
#  17,
#  11,
#  17,
#  0,
#  0,
#  11,
#  3,
#  11,
#  5,
#  9,
#  1,
#  0,
#  17,
#  2,
#  3,
#  17,
#  2,
#  9,
#  2,
#  10,
#  0,
#  4,
#  3,
#  2,
#  7,
#  9,
#  10,
#  9,
#  3,
#  0,
#  13,
#  0,
#  7,
#  0,
#  11,
#  15,
#  7,
#  11,
#  17,
#  17,
#  4,
#  17,
#  0,
#  11,
#  3,
#  11,
#  3,
#  3,
#  9,
#  16,
#  2,
#  0,
#  4,
#  16,
#  11,
#  17,
#  17,
#  11,
#  7,
#  3,
#  11,
#  7,
#  17,
#  11,
#  13,
#  3,
#  0,
#  2,
#  0,
#  3,
#  9,
#  17,
#  17,
#  1,
#  17,
#  14,
#  0,
#  10,
#  6,
#  3,
#  7,
#  0,
#  0,
#  3,
#  11,
#  9,
#  9,
#  0,
#  17,
#  10,
#  14,
#  14,
#  17,
#  11,
#  13,
#  8,
#  4,
#  0,
#  3,
#  17,
#  0,
#  3,
#  17,
#  3,
#  0,
#  0,
#  3,
#  17,
#  8,
#  10,
#  11,
#  3,
#  8,
#  17,
#  17,
#  0,
#  2,
#  3,
#  4,
#  17,
#  3,
#  3,
#  0,
#  0,
#  17,
#  22,
#  10,
#  3,
#  1,
#  5,
#  11,
#  3,
#  3,
#  11,
#  3,
#  14,
#  3,
#  11,
#  13,
#  3,
#  17,
#  0,
#  11,
#  3,
#  17,
#  3,
#  15,
#  9,
#  0,
#  14,
#  2,
#  11,
#  12,
#  7,
#  3,
#  17,
#  11,
#  3,
#  2,
#  17,
#  3,
#  3,
#  3,
#  0,
#  0,
#  10,
#  14,
#  14,
#  8,
#  0,
#  3,
#  17,
#  1,
#  0,
#  11,
#  0,
#  7,
#  11,
#  3,
#  17,
#  3,
#  13,
#  17,
#  17,
#  17,
#  9,
#  0,
#  11,
#  8,
#  0,
#  17,
#  0,
#  0,
#  2,
#  3,
#  11,
#  7,
#  9,
#  0,
#  6,
#  0,
#  11,
#  11,
#  17,
#  11,
#  17,
#  17,
#  23,
#  3,
#  15,
#  0,
#  3,
#  0,
#  17,
#  3,
#  14,
#  17,
#  17,
#  2,
#  3,
#  3,
#  11,
#  11,
#  11,
#  1,
#  3,
#  3,
#  16,
#  10,
#  11,
#  18,
#  11,
#  11,
#  2,
#  17,
#  9,
#  9,
#  2,
#  17,
#  0,
#  0,
#  3,
#  0,
#  11,
#  7,
#  0,
#  11,
#  12,
#  11,
#  11,
#  17,
#  17,
#  12,
#  14,
#  0,
#  12,
#  17,
#  1,
#  11,
#  5,
#  3,
#  3,
#  3,
#  15,
#  0,
#  11,
#  0,
#  17,
#  4,
#  9,
#  0,
#  5,
#  16,
#  0,
#  20,
#  21,
#  14,
#  11,
#  10,
#  3,
#  10,
#  17,
#  11,
#  11,
#  3,
#  2,
#  11,
#  3,
#  15,
#  0,
#  17,
#  7,
#  11,
#  3,
#  11,
#  3,
#  9,
#  17,
#  0,
#  12,
#  17,
#  17,
#  3,
#  0,
#  11,
#  11,
#  11,
#  0,
#  3,
#  11,
#  7,
#  13,
#  0,
#  11,
#  3,
#  3,
#  17,
#  0,
#  11,
#  17,
#  3,
#  5,
#  8,
#  17,
#  0,
#  17,
#  0,
#  3,
#  0,
#  15,
#  3,
#  3,
#  11,
#  3,
#  9,
#  0,
#  13,
#  15,
#  8,
#  2,
#  11,
#  17,
#  17,
#  14,
#  11,
#  4,
#  3,
#  11,
#  11,
#  3,
#  10,
#  3,
#  18,
#  11,
#  17,
#  10,
#  11,
#  21,
#  3,
#  11,
#  3,
#  16,
#  0,
#  5,
#  0,
#  0,
#  3,
#  0,
#  12,
#  11,
#  17,
#  17,
#  0,
#  15,
#  15,
#  0,
#  11,
#  21,
#  3,
#  14,
#  0,
#  12,
#  0,
#  3,
#  0,
#  3,
#  0,
#  14,
#  17,
#  0,
#  9,
#  0,
#  1,
#  22,
#  5,
#  4,
#  17,
#  17,
#  1,
#  17,
#  17,
#  5,
#  3,
#  7,
#  3,
#  9,
#  3,
#  17,
#  9,
#  17,
#  8,
#  11,
#  0,
#  3,
#  2,
#  18,
#  13,
#  10,
#  0,
#  4,
#  2,
#  0,
#  13,
#  11,
#  16,
#  11,
#  11,
#  0,
#  11,
#  11,
#  17,
#  8,
#  15,
#  17,
#  11,
#  4,
#  7,
#  9,
#  11,
#  11,
#  17,
#  10,
#  0,
#  2,
#  11,
#  14,
#  0,
#  17,
#  3,
#  7,
#  16,
#  17,
#  16,
#  3,
#  16,
#  10,
#  3,
#  8,
#  17,
#  17,
#  11,
#  2,
#  7,
#  4,
#  3,
#  3,
#  3,
#  17,
#  3,
#  15,
#  17,
#  2,
#  21,
#  0,
#  4,
#  3,
#  8,
#  0,
#  5,
#  11,
#  2,
#  3,
#  3,
#  6,
#  17,
#  3,
#  0,
#  17,
#  3,
#  17,
#  11,
#  11,
#  11,
#  3,
#  17,
#  7,
#  3,
#  0,
#  20,
#  15,
#  17,
#  0,
#  3,
#  3,
#  3,
#  0,
#  3,
#  17,
#  11,
#  11,
#  3,
#  17,
#  13,
#  3,
#  3,
#  14,
#  1,
#  3,
#  4,
#  8,
#  11,
#  11,
#  3,
#  11,
#  3,
#  3,
#  11,
#  3,
#  17,
#  0,
#  17,
#  11,
#  17,
#  0,
#  11,
#  24,
#  17,
#  7,
#  3,
#  11,
#  9,
#  13,
#  3,
#  17,
#  11,
#  3,
#  2,
#  11,
#  5,
#  3,
#  3,
#  1,
#  0,
#  0,
#  5,
#  3,
#  3,
#  0,
#  3,
#  11,
#  0,
#  2,
#  14,
#  11,
#  0,
#  17,
#  11,
#  17,
#  17,
#  2,
#  10,
#  11,
#  9,
#  17,
#  10,
#  2,
#  11,
#  8,
#  0,
#  0,
#  0,
#  17,
#  3,
#  4,
#  6,
#  11,
#  17,
#  3,
#  17,
#  0,
#  1,
#  11,
#  17,
#  1,
#  10,
#  3,
#  8,
#  3,
#  5,
#  10,
#  3,
#  0,
#  6,
#  0,
#  17,
#  14,
#  17,
#  11,
#  5,
#  2,
#  3,
#  9,
#  16,
#  11,
#  11,
#  13,
#  3,
#  3,
#  10,
#  0,
#  3,
#  11,
#  9,
#  0,
#  8,
#  0,
#  0,
#  3,
#  8,
#  17,
#  2,
#  3,
#  3,
#  0,
#  1,
#  14,
#  3,
#  11,
#  17,
#  17,
#  16,
#  3,
#  4,
#  11,
#  3,
#  11,
#  10,
#  14,
#  11,
#  3,
#  3,
#  7,
#  3,
#  4,
#  3,
#  0,
#  1,
#  17,
#  19,
#  8,
#  17,
#  0,
#  11,
#  0,
#  9,
#  3,
#  3,
#  8,
#  7,
#  8,
#  17,
#  2,
#  17,
#  0,
#  16,
#  10,
#  7,
#  11,
#  14,
#  11,
#  11,
#  3,
#  15,
#  0,
#  1,
#  3,
#  3,
#  3,
#  0,
#  3,
#  18,
#  15,
#  11,
#  0,
#  11,
#  17,
#  15,
#  0,
#  11,
#  3,
#  7,
#  12,
#  3,
#  12,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  9,
#  0,
#  12,
#  7,
#  3,
#  5,
#  3,
#  18,
#  1,
#  5,
#  3,
#  0,
#  17,
#  17,
#  15,
#  17,
#  13,
#  3,
#  11,
#  4,
#  0,
#  2,
#  0,
#  0,
#  0,
#  11,
#  3,
#  18,
#  17,
#  0,
#  8,
#  3,
#  0,
#  9,
#  17,
#  1,
#  15,
#  9,
#  7,
#  8,
#  11,
#  17,
#  12,
#  10,
#  4,
#  24,
#  4,
#  17,
#  0,
#  3,
#  11,
#  3,
#  10,
#  3,
#  0,
#  17,
#  16,
#  10,
#  3,
#  11,
#  3,
#  2,
#  11,
#  17,
#  17,
#  2,
#  17,
#  3,
#  17,
#  11,
#  3,
#  4,
#  4,
#  15,
#  3,
#  17,
#  3,
#  11,
#  7,
#  11,
#  3,
#  11,
#  15,
#  11,
#  10,
#  7,
#  3,
#  11,
#  17,
#  9,
#  0,
#  15,
#  2,
#  3,
#  3,
#  17,
#  17,
#  0,
#  15,
#  17,
#  3,
#  0,
#  3,
#  14,
#  3,
#  17,
#  0,
#  11,
#  11,
#  0,
#  15,
#  14,
#  0,
#  0,
#  4,
#  3,
#  3,
#  0,
#  11,
#  11,
#  16,
#  13,
#  11,
#  17,
#  0,
#  17,
#  11,
#  0,
#  7,
#  16,
#  0,
#  0,
#  6,
#  11,
#  7,
#  1,
#  11,
#  17,
#  0,
#  15,
#  17,
#  3,
#  8,
#  13,
#  17,
#  0,
#  15,
#  4,
#  6,
#  11,
#  11,
#  9,
#  17,
#  7,
#  17,
#  17,
#  3,
#  3,
#  17,
#  0,
#  11,
#  3,
#  10,
#  11,
#  3,
#  17,
#  4,
#  3,
#  10,
#  3,
#  15,
#  4,
#  11,
#  3,
#  11,
#  7,
#  3,
#  3,
#  24,
#  17,
#  19,
#  11,
#  0,
#  3,
#  5,
#  8,
#  0,
#  11,
#  11,
#  17,
#  0,
#  3,
#  4,
#  0,
#  11,
#  3,
#  0,
#  17,
#  7,
#  18,
#  8,
#  3,
#  11,
#  11,
#  7,
#  11,
#  16,
#  ...]

# %% [markdown]
# # Complete Code

# %%
# 주어진 훈련 데이터 경로
train_csv = sorted(glob('dataset/train/train/*/*.csv')) 
train_jpg = sorted(glob('dataset/train/train/*/*.jpg'))
train_json = sorted(glob('dataset/train/train/*/*.json'))

crops = []
diseases = []
risks = []
labels = []

# 훈련데이터 로드
for i in range(len(train_json)):
    with open(train_json[i], 'r') as f:
        sample = json.load(f)
        crop = sample['annotations']['crop']
        disease = sample['annotations']['disease']
        risk = sample['annotations']['risk']
        label=f"{crop}_{disease}_{risk}"
    
        crops.append(crop)
        diseases.append(disease)
        risks.append(risk)
        labels.append(label)

label_unique = sorted(np.unique(labels))
label_unique = {key:value for key,value in zip(label_unique, range(len(label_unique)))}

labels = [label_unique[k] for k in labels]


# 이미지 로드 함수 / 로드 후 (512, 384)로 사이즈 변환 ==> (원본 사이즈에서 width 384인 샘플이 많아서 (512, 384) 사이즈로 변환)
def img_load(path):
    img = cv2.imread(path)[:,:,::-1]
    img = cv2.resize(img, (384, 512)) # width , height! 
    return img

# 이미지 로드
imgs = [img_load(k) for k in tqdm(train_jpg)]
# Out:
# 100%|██████████| 5767/5767 [00:25<00:00, 224.45it/s]

# %% [markdown]
# # 데이터로더와 모델 정의

# %%
class Custom_dataset(Dataset):
    def __init__(self, img_paths, labels, mode='train'):
        self.img_paths = img_paths
        self.labels = labels
        self.mode=mode
    def __len__(self):
        return len(self.img_paths)
    def __getitem__(self, idx):
        img = self.img_paths[idx]
        if self.mode=='train':
            augmentation = random.randint(0,2)
            if augmentation==1:  #if 1, do horizontal flip 
                img = img[::-1].copy() # width , horizontal flip
            elif augmentation==2: # if 2, do vertical flip
                img = img[:,::-1].copy() # height,  vertical flip
        img = transforms.ToTensor()(img)
        if self.mode=='test':
            return img
        
        label = self.labels[idx]
        return img,label

# %% [markdown]
# # 모델 정의

# %%
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.model = timm.create_model('efficientnet_b0', pretrained=True, num_classes=25) # change
        
    def forward(self, x):
        x = self.model(x)
        return x

# %% [markdown]
# # 데이터 분리 및 로더 정의

# %%
# KFold
folds = []
k_folds = 5
kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# Start print
print('--------------------------------')

for fold, (train_idx, valid_idx) in enumerate(kf.split(imgs)):
    # Print
    print(f'FOLD {fold}')
    print('--------------------------------')
    folds.append((train_idx, valid_idx))
    print(fold)

fold=0
train_idx, valid_idx = folds[fold]

batch_size = 4
epochs = 15

# Train
train_dataset = Custom_dataset(np.array(imgs)[train_idx], np.array(labels)[train_idx], mode='train')
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=batch_size, pin_memory=True, num_workers=4)

# Validation 
valid_dataset = Custom_dataset(np.array(imgs)[valid_idx], np.array(labels)[valid_idx], mode='valid')
valid_loader = DataLoader(valid_dataset, shuffle=False, batch_size=batch_size, pin_memory=True, num_workers=4)
# Out:
# --------------------------------
# FOLD 0
# --------------------------------
# 0
# FOLD 1
# --------------------------------
# 1
# FOLD 2
# --------------------------------
# 2
# FOLD 3
# --------------------------------
# 3
# FOLD 4
# --------------------------------
# 4

# %% [markdown]
# # 훈련

# %%
device = torch.device('cuda')
model = Network().to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()
scaler = torch.cuda.amp.GradScaler() 

best=0
for epoch in range(epochs):
    start=time.time()
    train_loss = 0
    train_pred=[]
    train_y=[]
    # Training
    model.train()
    for batch in (train_loader):
        # batch -> (inp,lbl)
        optimizer.zero_grad() # zero the parameter gradients
        inputs = torch.tensor(batch[0], dtype=torch.float32, device=device)
        labels = torch.tensor(batch[1], dtype=torch.long, device=device)
        with torch.cuda.amp.autocast():
            outputs = model(inputs)       #  model(inputs)
        loss = criterion(outputs, labels) #  criterion(outputs, labels)

        # see "Typical Mixed O"
        scaler.scale(loss).backward() # loss.backward() 
        scaler.step(optimizer) # optimizer.step()
        scaler.update()
        
        train_loss += loss.item()/len(train_loader)
        train_pred += outputs.argmax(1).detach().cpu().numpy().tolist() # torch.max(outputs, 1)
        train_y += labels.detach().cpu().numpy().tolist()
        
    
    train_f1 = accuracy_function(train_y, train_pred)
    
    model.eval()
    valid_loss = 0
    valid_pred=[]
    valid_y=[]

    #Validation
    with torch.no_grad():
        for batch in (valid_loader):
            inputs = torch.tensor(batch[0], dtype=torch.float32, device=device)
            labels = torch.tensor(batch[1], dtype=torch.long, device=device)
            with torch.cuda.amp.autocast():
                outputs = model(inputs)
            loss = criterion(outputs, labels)
            valid_loss += loss.item()/len(valid_loader)
            valid_pred += outputs.argmax(1).detach().cpu().numpy().tolist()
            valid_y += labels.detach().cpu().numpy().tolist()
        valid_f1 = accuracy_function(valid_y, valid_pred)
    if valid_f1>=best:
        best=valid_f1
        model_save(model, valid_f1, f'model/eff-b0.pth')
    # visualize the training process with the evaluation metric
    TIME = time.time() - start
    print(f'epoch : {epoch+1}/{epochs}    time : {TIME:.0f}s/{TIME*(epochs-epoch-1):.0f}s')
    print(f'TRAIN    loss : {train_loss:.5f}    f1 : {train_f1:.5f}')
    print(f'VALID    loss : {valid_loss:.5f}    f1 : {valid_f1:.5f}    best : {best:.5f}')
